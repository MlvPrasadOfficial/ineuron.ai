# %%
d = df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize = (10,10))

# %%
d = df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (20, 20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a1b56cd30>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b77af98>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b905438>],
#       dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20, 20), fontsize = 26, autopct = '%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a286c9208>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d9f2518>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a2879a978>],
#       dtype=object)

# %%
[0.1]*4
# Out:
# [0.1, 0.1, 0.1, 0.1]

# %%
series = pd.Series([0.2]*4, index = ['a','b','c', 'd'], name = 'Pie Plot')
series.plot.pie()
