# %% [markdown]
# # Web APIs

# %%
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
type(resp)
# Out:
# requests.models.Response

# %%
data = resp.json()
data[2]['user']['id']
# Out:
# 5236149

# %%
import pandas as pd 
issues = pd.DataFrame(data)
issues
# Out:
#                                              assignee  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20  {'login': 'parkerdgabel', 'id': 21162926, 'nod...
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
#
#                                             assignees author_association  \
# 0                                                  []             MEMBER
# 1                                                  []             MEMBER
# 2                                                  []        CONTRIBUTOR
# 3                                                  []               NONE
# 4                                                  []               NONE
# 5                                                  []             MEMBER
# 6                                                  []        CONTRIBUTOR
# 7                                                  []               NONE
# 8                                                  []               NONE
# 9                                                  []        CONTRIBUTOR
# 10                                                 []             MEMBER
# 11                                                 []               NONE
# 12                                                 []        CONTRIBUTOR
# 13                                                 []        CONTRIBUTOR
# 14                                                 []               NONE
# 15                                                 []               NONE
# 16                                                 []        CONTRIBUTOR
# 17                                                 []        CONTRIBUTOR
# 18                                                 []             MEMBER
# 19                                                 []             MEMBER
# 20  [{'login': 'parkerdgabel', 'id': 21162926, 'no...               NONE
# 21                                                 []             MEMBER
# 22                                                 []        CONTRIBUTOR
# 23                                                 []               NONE
# 24                                                 []               NONE
# 25                                                 []               NONE
# 26                                                 []        CONTRIBUTOR
# 27                                                 []        CONTRIBUTOR
# 28                                                 []        CONTRIBUTOR
# 29                                                 []             MEMBER
#
#                                                  body closed_at  comments  \
# 0   It's only used in one non-test place, and all ...      None         0
# 1                                                          None         0
# 2   Added `DataFrame.differences` and `Series.diff...      None         0
# 3   Hello,\r\n\r\nUnder some circumstances that I'...      None         1
# 4   #### Code Sample, a copy-pastable example if p...      None         1
# 5   #### Code Sample, a copy-pastable example if p...      None         1
# 6   - [x] closes #30843\r\n- [ ] tests added / pas...      None         0
# 7   I'm working to add a `CategoricalIndex` suppor...      None         1
# 8   ```python\r\ndf = pd.DataFrame([5, 10, 15, 5, ...      None         4
# 9   Currently the check only matches `.py` files. ...      None         0
# 10                                                         None         1
# 11  - [x] closes #30740\r\n- [x] tests added / pas...      None         6
# 12  I'm not really sure whether this is the correc...      None         2
# 13  Closes https://github.com/pandas-dev/pandas/is...      None         4
# 14  This is a place to discuss whether supporting ...      None         4
# 15  #### some example....\r\n\r\n```python\r\ndef ...      None         1
# 16  Fixes #30811 \r\nThis now will only detect typ...      None         0
# 17  Without supporting an incremental mode, the ru...      None         8
# 18  The section about imports here: https://github...      None         3
# 19  I ran a full benchmark on a separate machine l...      None         8
# 20  #### Code Sample\r\n\r\n```python\r\nimport pa...      None         3
# 21  Closes #27357\r\n\r\nTo show in code what I th...      None         1
# 22  - [ ] closes #xxxx\r\n- [ ] tests added / pass...      None         1
# 23  #### Code Sample, a copy-pastable example if p...      None         3
# 24  ## Overview\r\nI found that the number of line...      None         2
# 25  - [x] closes https://github.com/pandas-dev/pan...      None         6
# 26                                       More typing.      None         3
# 27  - [ ] closes #xxxx\r\n- [ ] tests added / pass...      None         8
# 28  If we construct MI with `nan`, and check the `...      None         9
# 29  - [X] xref #28822\r\n- [x] tests added / passe...      None         2
#
#                                          comments_url            created_at  \
# 0   https://api.github.com/repos/pandas-dev/pandas...  2020-01-09T17:05:39Z
# 1   https://api.github.com/repos/pandas-dev/pandas...  2020-01-09T16:37:45Z
# 2   https://api.github.com/repos/pandas-dev/pandas...  2020-01-09T16:14:08Z
# 3   https://api.github.com/repos/pandas-dev/pandas...  2020-01-09T16:05:04Z
# 4   https://api.github.com/repos/pandas-dev/pandas...  2020-01-09T15:13:53Z
# 5   https://api.github.com/repos/pandas-dev/pandas...  2020-01-09T14:55:58Z
# 6   https://api.github.com/repos/pandas-dev/pandas...  2020-01-09T13:27:14Z
# 7   https://api.github.com/repos/pandas-dev/pandas...  2020-01-09T11:26:55Z
# 8   https://api.github.com/repos/pandas-dev/pandas...  2020-01-09T11:09:49Z
# 9   https://api.github.com/repos/pandas-dev/pandas...  2020-01-09T07:28:35Z
# 10  https://api.github.com/repos/pandas-dev/pandas...  2020-01-09T04:55:16Z
# 11  https://api.github.com/repos/pandas-dev/pandas...  2020-01-09T04:44:29Z
# 12  https://api.github.com/repos/pandas-dev/pandas...  2020-01-09T01:32:17Z
# 13  https://api.github.com/repos/pandas-dev/pandas...  2020-01-08T21:49:10Z
# 14  https://api.github.com/repos/pandas-dev/pandas...  2020-01-08T21:21:25Z
# 15  https://api.github.com/repos/pandas-dev/pandas...  2020-01-08T16:55:32Z
# 16  https://api.github.com/repos/pandas-dev/pandas...  2020-01-08T15:10:33Z
# 17  https://api.github.com/repos/pandas-dev/pandas...  2020-01-08T09:13:20Z
# 18  https://api.github.com/repos/pandas-dev/pandas...  2020-01-08T01:28:01Z
# 19  https://api.github.com/repos/pandas-dev/pandas...  2020-01-07T18:06:36Z
# 20  https://api.github.com/repos/pandas-dev/pandas...  2020-01-07T16:45:16Z
# 21  https://api.github.com/repos/pandas-dev/pandas...  2020-01-07T15:44:56Z
# 22  https://api.github.com/repos/pandas-dev/pandas...  2020-01-07T12:35:03Z
# 23  https://api.github.com/repos/pandas-dev/pandas...  2020-01-07T11:49:26Z
# 24  https://api.github.com/repos/pandas-dev/pandas...  2020-01-07T05:59:47Z
# 25  https://api.github.com/repos/pandas-dev/pandas...  2020-01-06T23:35:31Z
# 26  https://api.github.com/repos/pandas-dev/pandas...  2020-01-06T22:38:46Z
# 27  https://api.github.com/repos/pandas-dev/pandas...  2020-01-06T21:20:51Z
# 28  https://api.github.com/repos/pandas-dev/pandas...  2020-01-06T18:30:30Z
# 29  https://api.github.com/repos/pandas-dev/pandas...  2020-01-06T17:32:37Z
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url  ...  \
# 0     https://github.com/pandas-dev/pandas/pull/30854  ...
# 1     https://github.com/pandas-dev/pandas/pull/30853  ...
# 2     https://github.com/pandas-dev/pandas/pull/30852  ...
# 3   https://github.com/pandas-dev/pandas/issues/30851  ...
# 4   https://github.com/pandas-dev/pandas/issues/30849  ...
# 5   https://github.com/pandas-dev/pandas/issues/30848  ...
# 6     https://github.com/pandas-dev/pandas/pull/30847  ...
# 7   https://github.com/pandas-dev/pandas/issues/30846  ...
# 8   https://github.com/pandas-dev/pandas/issues/30845  ...
# 9   https://github.com/pandas-dev/pandas/issues/30843  ...
# 10    https://github.com/pandas-dev/pandas/pull/30839  ...
# 11    https://github.com/pandas-dev/pandas/pull/30838  ...
# 12  https://github.com/pandas-dev/pandas/issues/30834  ...
# 13    https://github.com/pandas-dev/pandas/pull/30824  ...
# 14  https://github.com/pandas-dev/pandas/issues/30823  ...
# 15  https://github.com/pandas-dev/pandas/issues/30815  ...
# 16    https://github.com/pandas-dev/pandas/pull/30814  ...
# 17    https://github.com/pandas-dev/pandas/pull/30811  ...
# 18  https://github.com/pandas-dev/pandas/issues/30808  ...
# 19  https://github.com/pandas-dev/pandas/issues/30790  ...
# 20  https://github.com/pandas-dev/pandas/issues/30787  ...
# 21    https://github.com/pandas-dev/pandas/pull/30784  ...
# 22    https://github.com/pandas-dev/pandas/pull/30778  ...
# 23  https://github.com/pandas-dev/pandas/issues/30776  ...
# 24  https://github.com/pandas-dev/pandas/issues/30770  ...
# 25    https://github.com/pandas-dev/pandas/pull/30766  ...
# 26    https://github.com/pandas-dev/pandas/pull/30761  ...
# 27    https://github.com/pandas-dev/pandas/pull/30755  ...
# 28  https://github.com/pandas-dev/pandas/issues/30750  ...
# 29    https://github.com/pandas-dev/pandas/pull/30746  ...
#
#                                             milestone  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12                                               None
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
#
#                              node_id number  \
# 0   MDExOlB1bGxSZXF1ZXN0MzYxMDY1Mzgx  30854
# 1   MDExOlB1bGxSZXF1ZXN0MzYxMDUxNjM1  30853
# 2   MDExOlB1bGxSZXF1ZXN0MzYxMDQwMDU5  30852
# 3           MDU6SXNzdWU1NDc1NzEyMjc=  30851
# 4           MDU6SXNzdWU1NDc1Mzk1MzU=  30849
# 5           MDU6SXNzdWU1NDc1MjkwMzY=  30848
# 6   MDExOlB1bGxSZXF1ZXN0MzYwOTU4NzIz  30847
# 7           MDU6SXNzdWU1NDc0MTk4Mjg=  30846
# 8           MDU6SXNzdWU1NDc0MTA5ODg=  30845
# 9           MDU6SXNzdWU1NDczMDAzNzI=  30843
# 10  MDExOlB1bGxSZXF1ZXN0MzYwNzcwMjcx  30839
# 11  MDExOlB1bGxSZXF1ZXN0MzYwNzY3NTIw  30838
# 12          MDU6SXNzdWU1NDcxOTY3MTk=  30834
# 13  MDExOlB1bGxSZXF1ZXN0MzYwNjcwNjIx  30824
# 14          MDU6SXNzdWU1NDcxMDg2NTI=  30823
# 15          MDU6SXNzdWU1NDY5ODI4NjQ=  30815
# 16  MDExOlB1bGxSZXF1ZXN0MzYwNTA1ODUz  30814
# 17  MDExOlB1bGxSZXF1ZXN0MzYwMzU0MjAx  30811
# 18          MDU6SXNzdWU1NDY1OTQ4NTE=  30808
# 19          MDU6SXNzdWU1NDY0Mjg5MDY=  30790
# 20          MDU6SXNzdWU1NDYzODk1Nzg=  30787
# 21  MDExOlB1bGxSZXF1ZXN0MzYwMDQ5MTEz  30784
# 22  MDExOlB1bGxSZXF1ZXN0MzU5OTcwODEz  30778
# 23          MDU6SXNzdWU1NDYyNDA4NzE=  30776
# 24          MDU6SXNzdWU1NDYwOTY0Nzg=  30770
# 25  MDExOlB1bGxSZXF1ZXN0MzU5NzU4NjQ0  30766
# 26  MDExOlB1bGxSZXF1ZXN0MzU5NzQzOTk0  30761
# 27  MDExOlB1bGxSZXF1ZXN0MzU5NzE4Nzg2  30755
# 28          MDU6SXNzdWU1NDU4NzE2MTU=  30750
# 29  MDExOlB1bGxSZXF1ZXN0MzU5NjM4MDAw  30746
#
#                                          pull_request  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12                                                NaN
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14                                                NaN
# 15                                                NaN
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23                                                NaN
# 24                                                NaN
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28                                                NaN
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                     repository_url state  \
# 0   https://api.github.com/repos/pandas-dev/pandas  open
# 1   https://api.github.com/repos/pandas-dev/pandas  open
# 2   https://api.github.com/repos/pandas-dev/pandas  open
# 3   https://api.github.com/repos/pandas-dev/pandas  open
# 4   https://api.github.com/repos/pandas-dev/pandas  open
# 5   https://api.github.com/repos/pandas-dev/pandas  open
# 6   https://api.github.com/repos/pandas-dev/pandas  open
# 7   https://api.github.com/repos/pandas-dev/pandas  open
# 8   https://api.github.com/repos/pandas-dev/pandas  open
# 9   https://api.github.com/repos/pandas-dev/pandas  open
# 10  https://api.github.com/repos/pandas-dev/pandas  open
# 11  https://api.github.com/repos/pandas-dev/pandas  open
# 12  https://api.github.com/repos/pandas-dev/pandas  open
# 13  https://api.github.com/repos/pandas-dev/pandas  open
# 14  https://api.github.com/repos/pandas-dev/pandas  open
# 15  https://api.github.com/repos/pandas-dev/pandas  open
# 16  https://api.github.com/repos/pandas-dev/pandas  open
# 17  https://api.github.com/repos/pandas-dev/pandas  open
# 18  https://api.github.com/repos/pandas-dev/pandas  open
# 19  https://api.github.com/repos/pandas-dev/pandas  open
# 20  https://api.github.com/repos/pandas-dev/pandas  open
# 21  https://api.github.com/repos/pandas-dev/pandas  open
# 22  https://api.github.com/repos/pandas-dev/pandas  open
# 23  https://api.github.com/repos/pandas-dev/pandas  open
# 24  https://api.github.com/repos/pandas-dev/pandas  open
# 25  https://api.github.com/repos/pandas-dev/pandas  open
# 26  https://api.github.com/repos/pandas-dev/pandas  open
# 27  https://api.github.com/repos/pandas-dev/pandas  open
# 28  https://api.github.com/repos/pandas-dev/pandas  open
# 29  https://api.github.com/repos/pandas-dev/pandas  open
#
#                                                 title            updated_at  \
# 0                              CLN: remove pydt_to_i8  2020-01-09T17:05:39Z
# 1      REF: share searchsorted and insert for DTI/TDI  2020-01-09T16:37:45Z
# 2   ENH: Added DataFrame.differences and Series.di...  2020-01-09T17:13:06Z
# 3   Pandas read_excel sometimes using xlrd which h...  2020-01-09T17:00:59Z
# 4      read_fwf reading large numbers as object dtype  2020-01-09T17:01:11Z
# 5   Series/DataFrame.rename(<mapper>, level=None) ...  2020-01-09T15:10:14Z
# 6   BLD: Run flake8 check on Cython files in pre-c...  2020-01-09T17:29:57Z
# 7   Cannot `remove_unused_categories` for Categori...  2020-01-09T13:50:00Z
# 8                         numexpr inconsistent result  2020-01-09T12:48:19Z
# 9   pre-commit check for flake8 doesn't check Cyth...  2020-01-09T07:28:35Z
# 10                                     TYP: __array__  2020-01-09T17:08:55Z
# 11  BUG: added missing fill_na parameter to DataFr...  2020-01-09T17:54:00Z
# 12  Feature Request: context manager in which NaN ...  2020-01-09T09:33:46Z
# 13              BUG: BooleanArray.value_counts dropna  2020-01-09T17:52:16Z
# 14                    Sub-nanosecond datetime support  2020-01-09T00:25:05Z
# 15  like old issue #2936:  df.apply(foo) will run ...  2020-01-09T16:34:11Z
# 16         BLD: More lightweight mypy pre-commit hook  2020-01-09T06:26:46Z
# 17  BLD: Remove mypy from pre-commit as long its a...  2020-01-09T17:47:32Z
# 18     DOC: Move import conventions from wiki to docs  2020-01-08T11:25:39Z
# 19  PERF: performance regression in 1.0 compared t...  2020-01-09T12:22:07Z
# 20  Unexpected behavior in cut() with nullable Int...  2020-01-09T01:05:00Z
# 21          API: DataFrame.take always returns a copy  2020-01-07T16:23:51Z
# 22                            [WIP] style NA in reprs  2020-01-07T12:35:18Z
# 23                      concat with same column names  2020-01-07T21:11:11Z
# 24  pandas.read_csv of S3 gets inconsistent result...  2020-01-07T21:18:34Z
# 25  BUG: Fix reindexing with multi-indexed DataFrames  2020-01-09T07:29:26Z
# 26                    TYP: type up parts of series.py  2020-01-09T17:10:16Z
# 27                              CI: Unify tests cases  2020-01-09T17:11:29Z
# 28  NA is not included in MultiIndex.levels if we ...  2020-01-08T20:52:03Z
# 29        CI: Using docstring validator from numpydoc  2020-01-08T16:08:10Z
#
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                  user
# 0   {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 1   {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 2   {'login': 'fujiaxiang', 'id': 5236149, 'node_i...
# 3   {'login': 'mhooreman', 'id': 7373718, 'node_id...
# 4   {'login': 'TonyFhh', 'id': 32705631, 'node_id'...
# 5   {'login': 'simonjayhawkins', 'id': 13159005, '...
# 6   {'login': 'xhochy', 'id': 70274, 'node_id': 'M...
# 7   {'login': 'fujiisoup', 'id': 6815844, 'node_id...
# 8   {'login': 'misantroop', 'id': 23288150, 'node_...
# 9   {'login': 'xhochy', 'id': 70274, 'node_id': 'M...
# 10  {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 11  {'login': 'tanmay1618', 'id': 12470734, 'node_...
# 12  {'login': 'fujiaxiang', 'id': 5236149, 'node_i...
# 13  {'login': 'TomAugspurger', 'id': 1312546, 'nod...
# 14  {'login': 'wmayner', 'id': 1775632, 'node_id':...
# 15  {'login': 'kerwin6182828', 'id': 36542293, 'no...
# 16  {'login': 'xhochy', 'id': 70274, 'node_id': 'M...
# 17  {'login': 'xhochy', 'id': 70274, 'node_id': 'M...
# 18  {'login': 'datapythonista', 'id': 10058240, 'n...
# 19  {'login': 'jorisvandenbossche', 'id': 1020496,...
# 20  {'login': 'sdmccabe', 'id': 10427730, 'node_id...
# 21  {'login': 'jorisvandenbossche', 'id': 1020496,...
# 22  {'login': 'TomAugspurger', 'id': 1312546, 'nod...
# 23  {'login': 'krishnachouhan', 'id': 9086076, 'no...
# 24  {'login': 'fullflu', 'id': 9534465, 'node_id':...
# 25  {'login': 'ChrisRobo', 'id': 7751383, 'node_id...
# 26  {'login': 'topper-123', 'id': 26364415, 'node_...
# 27  {'login': 'MomIsBestFriend', 'id': 50263213, '...
# 28  {'login': 'charlesdong1991', 'id': 9269816, 'n...
# 29  {'login': 'datapythonista', 'id': 10058240, 'n...
#
# [30 rows x 24 columns]
